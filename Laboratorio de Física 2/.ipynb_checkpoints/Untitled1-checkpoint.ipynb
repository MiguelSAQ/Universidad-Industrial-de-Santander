# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
# Datos
y = [0, 0.8, 1.6, 3.2, 4.8, 6.5, 8.1, 9.7, 11.3, 12.9, 14.5, 16.1, 17.7, 19.3] # [mm]
I = [1.00, 0.95, 0.80, 0.39, 0.079, 0.003, 0.036, 0.043, 0.013, 0.0003, 0.012, 0.015, 0.0044, 0.0003]

# Constantes
λ = 0.0006328 # [mm]
L = 1000 # [mm]

# %%
def equation(z, I_sol):  # Función para resolver la ecuación
    return (np.sin(z)**2 / z**2) - I_sol  # Ecuacion a resolver: Sin(β)^2/β^2 = 0 
 
β = np.pi / 2 # Estimación inicial
β = []  # Lista para almacenar las soluciones

for I_sol in I_values:   # Itera sobre cada valor de I (intensidad relativa) y resuelve la ecuación                             
    solution = fsolve(equation, z0, args=(I_sol))[0]  # Resuelve la ecuación y guarda la solución
    β.append(round(solution, 2))
    
print(f"β = {
# Out:
# Z solutions:, -0.0, 0.39, 0.81, 1.6, 2.4, 2.98, 2.62, 2.58, 2.81, 3.09, 2.83, 2.79, 2.94, 3.09

# %%
a_solutions = np.zeros(len(y))

for i in range(len(a_solutions)):
    if y[i] == 0:
        a_solutions[i] = 0.0
    else:
        a_solutions[i] = (z_solutions[i] * λ * np.sqrt(y[i]**2 + L**2)) / (np.pi * y[i])

a = round(np.mean(a_solutions), 1)
print(f"El ancho de la rendija es de: {a} mm")
# Out:
# El ancho de la rendija es de: 0.1 mm

# %%
y_teo = np.linspace(0.1, 20, 100)
I_teo = np.zeros(100)

for i in range(100):
    if y_teo[i] == 0:
        I_teo[i] = 1
    else:
        I_teo[i] = (np.sin( (np.pi * y_teo[i] * a) / (λ * np.sqrt( y_teo[i]**2 + L**2 )) )**2 /
                    ((np.pi * y_teo[i] * a) / (λ * np.sqrt( y_teo[i]**2 + L**2 )))**2)

    
plt.figure(figsize=(8, 6))
plt.scatter(y, I, label="Datos experimentales", color="red")
plt.title("Relative intensity as a function of distance from the central maximum", fontweight='bold')
plt.xlabel("Position Relative to Central Maximum (mm)")
plt.ylabel("Relative Intensity")
plt.grid()
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.scatter(y, I, label="Datos experimentales", color="red")
plt.plot(y_teo,I_teo, label="Función de interpolación", color="Blue", linestyle = "--")
plt.title("Relative intensity as a function of distance from the central maximum", fontweight='bold')
plt.xlabel("Position Relative to Central Maximum (mm)")
plt.ylabel("Relative Intensity")
plt.grid()
plt.legend()
plt.show()
