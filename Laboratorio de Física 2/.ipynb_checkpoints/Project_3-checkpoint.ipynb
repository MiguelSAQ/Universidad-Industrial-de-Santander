# %% [markdown]
# # Proyecto 3. Resistividad

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Parte 1 (Constantán, 0.4mm)

# %% [markdown]
# ### Fase 1: Medición directa de la resistencia

# %%
# Datos
L_A_P11 =  np.array([795774.881,1591549.762,2387324.643,3183099.524,3978874.405,4774649.286,5570424.167,6366199.048,7161973.929,7957748.81])
R_P11 = np.array([1.2,1.5,1.9,2.4,2.7,3,3.6,4,4.3,4.4])

# Ajuste
coef_P11 = np.polyfit(L_A_P11, R_P11, 1)
fit_P11 = np.polyval(coef_P11, L_A_P11)
X_P11 = np.linspace(0, 7957748.81, 100)
Y_Exp_P11 = X_P11 * coef_P11[0] + coef_P11[1]
Y_Teo_P11 = X_P11 * 4.9*10**(-7)

# Grafica
plt.scatter(L_A_P11, R_P11, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P11, Y_Exp_P11, linestyle='--', color='r', label=f'Resistividad experimental = 4.78 × 10⁻⁷')
plt.plot(X_P11, Y_Teo_P11, linestyle='--', color='b', label=f'Resistividad teorica = 4.90 × 10⁻⁷ ')

plt.title("Fase 1: Medición Directa de la Resistencia \n Constantán de 0.4 mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Fase 2: Medición indirecta de la resistencia

# %%
# Datos
L_A_P12 =  np.array([795774.881,1591549.762,2387324.643,3183099.524,3978874.405,4774649.286,5570424.167,6366199.048,7161973.929,7957748.81])
R_P12 = np.array([0.457142857,0.871428571,1.3,1.7,2.157142857,2.528571429,2.914285714,3.314285714,3.7,4.242857143])

# Ajuste
coef_P12 = np.polyfit(L_A_P12, R_P12, 1)
fit_P12 = np.polyval(coef_P12, L_A_P12)
X_P12 = np.linspace(0, 7957748.81, 100)
Y_Exp_P12 = X_P12 * coef_P12[0] + coef_P12[1]
Y_Teo_P12 = X_P12 * 4.9*10**(-7)

# Grafica
plt.scatter(L_A_P12, R_P12, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P12, Y_Exp_P12, linestyle='--', color='r', label=f'Resistividad experimental = 5.17 × 10⁻⁷')
plt.plot(X_P12, Y_Teo_P12, linestyle='--', color='b', label=f'Resistividad teorica = 4.90 × 10⁻⁷ ')

plt.title("Fase 2: Medición Indirecta de la Resistencia \n Constantán de 0.25 mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Parte 2 (Constantán, 0.25mm)

# %% [markdown]
# ### Fase 1: Medición directa de la resistencia

# %%
# Datos
L_A_P21 = np.array([2037183.695, 4074367.391, 6111551.086, 8148734.782, 10185918.48, 12223102.17, 14260285.87, 16297469.56, 18334653.26, 20371836.95])
R_P21 = np.array([1.6, 2.7, 3.6, 4.7, 5.7, 6.8, 7.8, 8.9, 10, 10.8])

# Ajuste
coef_P21 = np.polyfit(L_A_P21, R_P21, 1)
fit_P21 = np.polyval(coef_P21, L_A_P21)
X_P21 = np.linspace(2037183.695, 20371836.95, 100)
Y_Exp_P21 = X_P21 * coef_P21[0] + coef_P21[1]
Y_Teo_P21 = X_P21 * 4.9*10**(-7)

# Grafica
plt.scatter(L_A_P21, R_P21, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P21, Y_Exp_P21, linestyle='--', color='r', label=f'Resistividad experimental = 5.08 × 10⁻⁷')
plt.plot(X_P21, Y_Teo_P21, linestyle='--', color='b', label=f'Resistividad teorica = 4.90 × 10⁻⁷ ')

plt.title("Fase 1: Medición Directa de la Resistencia \n Constantán de 0.25 mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Fase 2: Medición indirecta de la resistencia

# %%
# Datos
L_A_P22 = np.array([2037183.695, 4074367.391, 6111551.086, 8148734.782, 10185918.48, 12223102.17, 14260285.87, 16297469.56, 18334653.26, 20371836.95])
R_P22 = np.array([1.128571429, 2.2, 3.314285714, 4.385714286, 5.4, 6.442857143, 7.5, 8.485714286, 9.442857143, 10.38571429])

# Ajuste
coef_P22 = np.polyfit(L_A_P22, R_P22, 1)
fit_P22 = np.polyval(coef_P22, L_A_P22)
X_P22 = np.linspace(2037183.695, 20371836.95, 100)
Y_Exp_P22 = X_P22 * coef_P12[0] + coef_P22[1]
Y_Teo_P22 = X_P22 * 4.9*10**(-7)

# Grafica
plt.scatter(L_A_P22, R_P22, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P22, Y_Exp_P22, linestyle='--', color='r', label=f'Resistividad experimental = 5.06 × 10⁻⁷')
plt.plot(X_P22, Y_Teo_P22, linestyle='--', color='b', label=f'Resistividad teorica = 4.90 × 10⁻⁷ ')

plt.title("Fase 2: Medición Indirecta de la Resistencia \n Constantán de 0.25 mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Parte 3 (Cromo-Níquel, 0.35mm)

# %% [markdown]
# ### Fase 1: Medición directa de la resistencia

# %%
# Datos
L_A_P31 = np.array([1039379.436, 2078758.873, 3118138.309, 4157517.746, 5196897.182, 6236276.619, 7275656.055, 8315035.491, 9354414.928, 10393794.36])
R_P31 = np.array([1.5, 2.6, 3.8, 5, 6.1, 7.1, 8.2, 9.7, 10.7, 11.7])

# Ajuste
coef_P31 = np.polyfit(L_A_P31, R_P31, 1)
fit_P31 = np.polyval(coef_P31, L_A_P31)
X_P31 = np.linspace(1039379.436,10393794.36,100)
Y_Exp_P31 = X_P31 * coef_P31[0] + coef_P31[1]
Y_Teo_P31 = X_P31 * 1.11*10**(-6)

# Grafica
plt.scatter(L_A_P31, R_P31, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P31, Y_Exp_P31, linestyle='--', color='r', label=f'Resistividad experimental = 1.10 × 10⁻⁶')
plt.plot(X_P31, Y_Teo_P31, linestyle='--', color='b', label=f'Resistividad teorica = 1.11 × 10⁻⁶ ')

plt.title("Fase 1: Medición Directa de la Resistencia \n Cromo-Níquel de  0.35mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Fase 2: Medición indirecta de la resistencia

# %%
# Datos
L_A_P32 = np.array([1039379.436, 2078758.873, 3118138.309, 4157517.746, 5196897.182, 6236276.619, 7275656.055, 8315035.491, 9354414.928, 10393794.36])
R_P32 = np.array([1.214285714, 2.428571429, 3.6, 4.771428571, 5.828571429, 6.942857143, 8.057142857, 9.485714286, 10.32857143, 11.2])

# Ajuste
coef_P32 = np.polyfit(L_A_P32, R_P32, 1)
fit_P32 = np.polyval(coef_P32, L_A_P32)
X_P32 = np.linspace(1039379.436,10393794.36,100)
Y_Exp_P32 = X_P32 * coef_P32[0] + coef_P32[1]
Y_Teo_P32 = X_P32 * 1.11*10**(-6)

# Grafica
plt.scatter(L_A_P32, R_P32, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P32, Y_Exp_P32, linestyle='--', color='r', label=f'Resistividad experimental = 1.10 × 10⁻⁷')
plt.plot(X_P32, Y_Teo_P32, linestyle='--', color='b', label=f'Resistividad teorica = 1.11 × 10⁻⁷ ')

plt.title("Fase 2: Medición Indirecta de la Resistencia \n Cromo-Níquel de 0.35mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Parte 4 (Cromo-Níquel, 0.4mm)

# %% [markdown]
# ### Fase 1: Medición directa de la resistencia

# %%
# Datos
L_A_P41 = np.array([795774.881, 1591549.762, 2387324.643, 3183099.524, 3978874.405, 4774649.286, 5570424.167, 6366199.048, 7161973.929, 7957748.81])
R_P41 = np.array([1.4, 2.5, 3, 3.8, 4.7, 5.5, 6.4, 7.3, 8, 8.8])

# Ajuste
coef_P41 = np.polyfit(L_A_P41, R_P41, 1)
fit_P41 = np.polyval(coef_P41, L_A_P41)
X_P41 = np.linspace(795774.881, 7957748.81, 100)
Y_Exp_P41 = X_P41 * coef_P41[0] + coef_P41[1]
Y_Teo_P41 = X_P41 * 1.11*10**(-6)

# Grafica
plt.scatter(L_A_P41, R_P41, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P41, Y_Exp_P41, linestyle='--', color='r', label=f'Resistividad experimental = 1.02 × 10⁻⁶')
plt.plot(X_P41, Y_Teo_P41, linestyle='--', color='b', label=f'Resistividad teorica = 1.11 × 10⁻⁶ ')

plt.title("Fase 1: Medición Directa de la Resistencia \n Cromo-Níquel de  0.4mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Fase 2: Medición indirecta de la resistencia

# %%
# Datos
L_A_P42 = np.array([795774.881, 1591549.762, 2387324.643, 3183099.524, 3978874.405, 4774649.286, 5570424.167, 6366199.048, 7161973.929, 7957748.81])
R_P42 = np.array([0.942857143, 1.8, 2.671428571, 3.585714286, 4.414285714, 5.257142857, 6.085714286, 6.885714286, 7.671428571, 8.514285714])

# Ajuste
coef_P42 = np.polyfit(L_A_P42, R_P42, 1)
fit_P42 = np.polyval(coef_P42, L_A_P42)
X_P42 = np.linspace(795774.881, 7957748.81, 100)
Y_Exp_P42 = X_P42 * coef_P42[0] + coef_P42[1]
Y_Teo_P42 = X_P42 * 1.11*10**(-6)

# Grafica
plt.scatter(L_A_P42, R_P42, marker='o', color='k', label='Datos experimentales')
plt.plot(X_P42, Y_Exp_P42, linestyle='--', color='r', label=f'Resistividad experimental = 1.05 × 10⁻⁶')
plt.plot(X_P42, Y_Teo_P42, linestyle='--', color='b', label=f'Resistividad teorica = 1.11 × 10⁻⁶ ')

plt.title("Fase 2: Medición Indirecta de la Resistencia \n Cromo-Níquel de 0.4mm", fontweight='bold')

plt.xlabel("L/A  (1/m)")
plt.ylabel("Resistencia (Ω)")

plt.grid()
plt.legend()
plt.show()
